# %% [markdown]
# <a href="https://colab.research.google.com/github/kentokpara/CMSC6950_Project/blob/main/MRP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Waste Manageement and Recyling with ML**
#
# ---

# %%
#@title Import relevant modules
import numpy as np
import os
import PIL
import PIL.Image
# !pip install tensorflow
import tensorflow as tf
import tensorflow_datasets as tfds
import os
import zipfile
from pathlib import Path
import glob
import pandas as pd
# !pip install opencv-python
import cv2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.8/dist-packages (2.9.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.50.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.12)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.28.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow) (21.3)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from opencv-python) (1.21.6)

# %%
print(tf.__version__)
# Out:
# 2.9.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
local_zip = '/content/drive/MyDrive/Colab Notebooks/Trashnet.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/Colab-Notebooks')
zip_ref.close()

# %%
base_dir = '/Colab-Notebooks/dataset-resized'

# %%
try:
   import splitfolders as sf
except ModuleNotFoundError:
  # !pip install split-folders
  import splitfolders as sf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
input_folder = base_dir
output = '/Colab-Notebooks/Split'
 #where you want the split datasets saved
sf.ratio(input_folder, output=output, seed=42, ratio=(.8, .2)) 
# ratio of split are in order of train/val/ only.

base_dir = output
# Out:
# Copying files: 2527 files [00:00, 7831.25 files/s]

# %%
train_dataset = "/Colab-Notebooks/Split/train"
val_dataset = "/Colab-Notebooks/Split/val"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dataset,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=50,
    image_size=(180, 180),
)
# Out:
# Found 2019 files belonging to 6 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    val_dataset,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=50,
    image_size=(180, 180),
    shuffle=True,
)
# Out:
# Found 508 files belonging to 6 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
# !pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 24.3 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
for images, labels in val_ds:
  x_test = images
  y_test = labels

print(x_test.shape)
print(y_test.shape)
# Out:
# (8, 180, 180, 3)
# (8,)

# %%
for images, labels in train_ds:
  x_train = images
  y_train = labels

print(x_train.shape)
print(y_train.shape)
# Out:
# (19, 180, 180, 3)
# (19,)

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.Normalization(),
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomWidth(0.2),
        tf.keras.layers.RandomHeight(0.2),
    ]
)

# Setting the state of the normalization layer

# %%
def create_encoder():
    Xcept = tf.keras.applications.Xception(
        include_top=False, weights=None, input_shape=(180,180,3), pooling="avg"
    )

    inputs = tf.keras.Input(shape=(180,180,3))
    augmented = data_augmentation(inputs)
    outputs = Xcept(augmented)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="Xcept-encoder")
    return model


encoder = create_encoder()
encoder.summary()

learning_rate = 0.0001
batch_size = 100
hidden_units = 2048
projection_units = 128
num_epochs = 40
dropout_rate = 0.4
temperature = 0.07
# Out:
# Model: "Xcept-encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       7
#
#  xception (Functional)       (None, 2048)              20861480
#
# =================================================================
# Total params: 20,861,487
# Trainable params: 20,806,952
# Non-trainable params: 54,535
# _________________________________________________________________

# %%
def create_classifier(encoder, trainable=True):

    for layer in encoder.layers:
        layer.trainable = trainable

    inputs = tf.keras.Input(shape=(180,180,3))
    features = encoder(inputs)
    features = tf.keras.layers.Dropout(dropout_rate)(features)
    features = tf.keras.layers.Dense(hidden_units, activation="relu")(features)
    features = tf.keras.layers.Dropout(dropout_rate)(features)
    outputs = tf.keras.layers.Dense(6, activation="softmax")(features)

    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="Xcept-classifier")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
    )
    return model

# %%
encoder = create_encoder()
classifier = create_classifier(encoder)
classifier.summary()

history = classifier.fit(train_ds, batch_size=batch_size, epochs=num_epochs)
# Out:
# Model: "Xcept-classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  Xcept-encoder (Functional)  (None, 2048)              20861487
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 2048)              4196352
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 6)                 12294
#
# =================================================================
# Total params: 25,070,133
# Trainable params: 25,015,598
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/40
# 41/41 [==============================] - 51s 883ms/step - loss: 1.3705 - sparse_categorical_accuracy: 0.4616
# Epoch 2/40
# 41/41 [==============================] - 32s 789ms/step - loss: 1.0505 - sparse_categorical_accuracy: 0.6107
# Epoch 3/40
# 41/41 [==============================] - 29s 704ms/step - loss: 0.9087 - sparse_categorical_accuracy: 0.6632
# Epoch 4/40
# 41/41 [==============================] - 28s 683ms/step - loss: 0.8444 - sparse_categorical_accuracy: 0.6895
# Epoch 5/40
# 41/41 [==============================] - 26s 641ms/step - loss: 0.7627 - sparse_categorical_accuracy: 0.7202
# Epoch 6/40
# 41/41 [==============================] - 27s 645ms/step - loss: 0.7257 - sparse_categorical_accuracy: 0.7335
# Epoch 7/40
# 41/41 [==============================] - 23s 544ms/step - loss: 0.6708 - sparse_categorical_accuracy: 0.7672
# Epoch 8/40
# 41/41 [==============================] - 27s 658ms/step - loss: 0.6469 - sparse_categorical_accuracy: 0.7732
# Epoch 9/40
# 41/41 [==============================] - 24s 577ms/step - loss: 0.5867 - sparse_categorical_accuracy: 0.7935
# Epoch 10/40
# 41/41 [==============================] - 23s 544ms/step - loss: 0.5495 - sparse_categorical_accuracy: 0.8024
# Epoch 11/40
# 41/41 [==============================] - 23s 551ms/step - loss: 0.5632 - sparse_categorical_accuracy: 0.8034
# Epoch 12/40
# 41/41 [==============================] - 23s 559ms/step - loss: 0.5191 - sparse_categorical_accuracy: 0.8103
# Epoch 13/40
# 41/41 [==============================] - 22s 531ms/step - loss: 0.4594 - sparse_categorical_accuracy: 0.8430
# Epoch 14/40
# 41/41 [==============================] - 21s 509ms/step - loss: 0.4480 - sparse_categorical_accuracy: 0.8455
# Epoch 15/40
# 41/41 [==============================] - 22s 528ms/step - loss: 0.4565 - sparse_categorical_accuracy: 0.8390
# Epoch 16/40
# 41/41 [==============================] - 22s 543ms/step - loss: 0.4824 - sparse_categorical_accuracy: 0.8242
# Epoch 17/40
# 41/41 [==============================] - 19s 468ms/step - loss: 0.4056 - sparse_categorical_accuracy: 0.8529
# Epoch 18/40
# 41/41 [==============================] - 19s 472ms/step - loss: 0.3977 - sparse_categorical_accuracy: 0.8583
# Epoch 19/40
# 41/41 [==============================] - 19s 460ms/step - loss: 0.3515 - sparse_categorical_accuracy: 0.8752
# Epoch 20/40
# 41/41 [==============================] - 22s 542ms/step - loss: 0.3517 - sparse_categorical_accuracy: 0.8782
# Epoch 21/40
# 41/41 [==============================] - 18s 436ms/step - loss: 0.3333 - sparse_categorical_accuracy: 0.8831
# Epoch 22/40
# 41/41 [==============================] - 20s 467ms/step - loss: 0.3303 - sparse_categorical_accuracy: 0.8717
# Epoch 23/40
# 41/41 [==============================] - 18s 432ms/step - loss: 0.3221 - sparse_categorical_accuracy: 0.8806
# Epoch 24/40
# 41/41 [==============================] - 20s 489ms/step - loss: 0.2924 - sparse_categorical_accuracy: 0.8935
# Epoch 25/40
# 41/41 [==============================] - 17s 419ms/step - loss: 0.2863 - sparse_categorical_accuracy: 0.8975
# Epoch 26/40
# 41/41 [==============================] - 19s 450ms/step - loss: 0.2769 - sparse_categorical_accuracy: 0.9004
# Epoch 27/40
# 41/41 [==============================] - 17s 421ms/step - loss: 0.2864 - sparse_categorical_accuracy: 0.8985
# Epoch 28/40
# 41/41 [==============================] - 20s 490ms/step - loss: 0.2198 - sparse_categorical_accuracy: 0.9237
# Epoch 29/40
# 41/41 [==============================] - 17s 416ms/step - loss: 0.2139 - sparse_categorical_accuracy: 0.9247
# Epoch 30/40
# 41/41 [==============================] - 18s 452ms/step - loss: 0.2657 - sparse_categorical_accuracy: 0.9039
# Epoch 31/40
# 41/41 [==============================] - 17s 406ms/step - loss: 0.2683 - sparse_categorical_accuracy: 0.8995
# Epoch 32/40
# 41/41 [==============================] - 18s 445ms/step - loss: 0.2829 - sparse_categorical_accuracy: 0.8995
# Epoch 33/40
# 41/41 [==============================] - 17s 413ms/step - loss: 0.2394 - sparse_categorical_accuracy: 0.9168
# Epoch 34/40
# 41/41 [==============================] - 17s 419ms/step - loss: 0.2076 - sparse_categorical_accuracy: 0.9302
# Epoch 35/40
# 41/41 [==============================] - 17s 410ms/step - loss: 0.2402 - sparse_categorical_accuracy: 0.9113
# Epoch 36/40
# 41/41 [==============================] - 16s 389ms/step - loss: 0.1912 - sparse_categorical_accuracy: 0.9326
# Epoch 37/40
# 41/41 [==============================] - 16s 390ms/step - loss: 0.2368 - sparse_categorical_accuracy: 0.9158
# Epoch 38/40
# 41/41 [==============================] - 16s 404ms/step - loss: 0.1960 - sparse_categorical_accuracy: 0.9232
# Epoch 39/40
# 41/41 [==============================] - 17s 405ms/step - loss: 0.1732 - sparse_categorical_accuracy: 0.9371
# Epoch 40/40
# 41/41 [==============================] - 17s 409ms/step - loss: 0.1693 - sparse_categorical_accuracy: 0.9386

# %%
accuracy = classifier.evaluate(val_ds)[1]

print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 11/11 [==============================] - 1s 40ms/step - loss: 1.0606 - sparse_categorical_accuracy: 0.7382
# Test accuracy: 73.82%

# %%
plt.plot(history.history['sparse_categorical_accuracy'])
plt.title('Transfer Learning Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Transfer Learning Model Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
import tensorflow_addons as tfa

# %%
class SupervisedContrastiveLoss(tf.keras.losses.Loss):
    def __init__(self, temperature=1, name=None):
        super(SupervisedContrastiveLoss, self).__init__(name=name)
        self.temperature = temperature

    def __call__(self, labels, feature_vectors, sample_weight=None):
        # Normalize feature vectors
        feature_vectors_normalized = tf.math.l2_normalize(feature_vectors, axis=1)
        # Compute logits
        logits = tf.divide(
            tf.matmul(
                feature_vectors_normalized, tf.transpose(feature_vectors_normalized)
            ),
            self.temperature,
        )
        return tfa.losses.npairs_loss(tf.squeeze(labels), logits)


def add_projection_head(encoder):
    inputs = tf.keras.Input(shape=(180,180,3))
    features = encoder(inputs)
    outputs = tf.keras.layers.Dense(projection_units, activation="relu")(features)
    model = tf.keras.Model(
        inputs=inputs, outputs=outputs, name="encoder_with_projection-head"
    )
    return model

# %%
encoder = create_encoder()

encoder_with_projection_head = add_projection_head(encoder)
encoder_with_projection_head.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=SupervisedContrastiveLoss(temperature),
)

encoder_with_projection_head.summary()

history1_Loss = encoder_with_projection_head.fit(
    train_ds, batch_size=batch_size, epochs=num_epochs
)
# Out:
# Model: "encoder_with_projection-head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  Xcept-encoder (Functional)  (None, 2048)              20861487
#
#  dense_2 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 21,123,759
# Trainable params: 21,069,224
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/40
# 41/41 [==============================] - 24s 453ms/step - loss: 3.6745
# Epoch 2/40
# 41/41 [==============================] - 15s 378ms/step - loss: 3.5149
# Epoch 3/40
# 41/41 [==============================] - 16s 398ms/step - loss: 3.4789
# Epoch 4/40
# 41/41 [==============================] - 15s 365ms/step - loss: 3.4016
# Epoch 5/40
# 41/41 [==============================] - 17s 413ms/step - loss: 3.3490
# Epoch 6/40
# 41/41 [==============================] - 17s 399ms/step - loss: 3.2693
# Epoch 7/40
# 41/41 [==============================] - 16s 394ms/step - loss: 3.2373
# Epoch 8/40
# 41/41 [==============================] - 15s 375ms/step - loss: 3.2359
# Epoch 9/40
# 41/41 [==============================] - 15s 374ms/step - loss: 3.1061
# Epoch 10/40
# 41/41 [==============================] - 15s 353ms/step - loss: 3.0975
# Epoch 11/40
# 41/41 [==============================] - 18s 422ms/step - loss: 3.0659
# Epoch 12/40
# 41/41 [==============================] - 15s 353ms/step - loss: 3.0372
# Epoch 13/40
# 41/41 [==============================] - 15s 352ms/step - loss: 3.0109
# Epoch 14/40
# 41/41 [==============================] - 15s 367ms/step - loss: 3.0073
# Epoch 15/40
# 41/41 [==============================] - 16s 377ms/step - loss: 2.9126
# Epoch 16/40
# 41/41 [==============================] - 16s 385ms/step - loss: 2.9245
# Epoch 17/40
# 41/41 [==============================] - 15s 359ms/step - loss: 2.8951
# Epoch 18/40
# 41/41 [==============================] - 14s 351ms/step - loss: 2.8427
# Epoch 19/40
# 41/41 [==============================] - 19s 444ms/step - loss: 2.8598
# Epoch 20/40
# 41/41 [==============================] - 16s 377ms/step - loss: 2.8065
# Epoch 21/40
# 41/41 [==============================] - 15s 362ms/step - loss: 2.7661
# Epoch 22/40
# 41/41 [==============================] - 16s 399ms/step - loss: 2.7880
# Epoch 23/40
# 41/41 [==============================] - 17s 413ms/step - loss: 2.8249
# Epoch 24/40
# 41/41 [==============================] - 15s 370ms/step - loss: 2.7432
# Epoch 25/40
# 41/41 [==============================] - 16s 393ms/step - loss: 2.7291
# Epoch 26/40
# 41/41 [==============================] - 14s 343ms/step - loss: 2.6828
# Epoch 27/40
# 41/41 [==============================] - 15s 367ms/step - loss: 2.6604
# Epoch 28/40
# 41/41 [==============================] - 14s 341ms/step - loss: 2.6113
# Epoch 29/40
# 41/41 [==============================] - 14s 344ms/step - loss: 2.6748
# Epoch 30/40
# 41/41 [==============================] - 16s 395ms/step - loss: 2.6353
# Epoch 31/40
# 41/41 [==============================] - 15s 367ms/step - loss: 2.6424
# Epoch 32/40
# 41/41 [==============================] - 15s 353ms/step - loss: 2.6261
# Epoch 33/40
# 41/41 [==============================] - 15s 352ms/step - loss: 2.6158
# Epoch 34/40
# 41/41 [==============================] - 16s 386ms/step - loss: 2.5891
# Epoch 35/40
# 41/41 [==============================] - 15s 361ms/step - loss: 2.5509
# Epoch 36/40
# 41/41 [==============================] - 15s 363ms/step - loss: 2.5613
# Epoch 37/40
# 41/41 [==============================] - 15s 365ms/step - loss: 2.5673
# Epoch 38/40
# 41/41 [==============================] - 15s 369ms/step - loss: 2.5785
# Epoch 39/40
# 41/41 [==============================] - 15s 360ms/step - loss: 2.5147
# Epoch 40/40
# 41/41 [==============================] - 14s 344ms/step - loss: 2.5192

# %%
plt.plot(history1_Loss.history['loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
classifier = create_classifier(encoder, trainable=False)

history1 = classifier.fit(train_ds, batch_size=batch_size, epochs=num_epochs)

accuracy = classifier.evaluate(val_ds)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# Epoch 1/40
# 41/41 [==============================] - 6s 67ms/step - loss: 0.6076 - sparse_categorical_accuracy: 0.8058
# Epoch 2/40
# 41/41 [==============================] - 3s 73ms/step - loss: 0.2564 - sparse_categorical_accuracy: 0.9208
# Epoch 3/40
# 41/41 [==============================] - 3s 63ms/step - loss: 0.2190 - sparse_categorical_accuracy: 0.9262
# Epoch 4/40
# 41/41 [==============================] - 3s 62ms/step - loss: 0.2074 - sparse_categorical_accuracy: 0.9321
# Epoch 5/40
# 41/41 [==============================] - 3s 68ms/step - loss: 0.1834 - sparse_categorical_accuracy: 0.9450
# Epoch 6/40
# 41/41 [==============================] - 3s 68ms/step - loss: 0.1779 - sparse_categorical_accuracy: 0.9435
# Epoch 7/40
# 41/41 [==============================] - 3s 75ms/step - loss: 0.1546 - sparse_categorical_accuracy: 0.9529
# Epoch 8/40
# 41/41 [==============================] - 2s 58ms/step - loss: 0.1661 - sparse_categorical_accuracy: 0.9460
# Epoch 9/40
# 41/41 [==============================] - 3s 61ms/step - loss: 0.1586 - sparse_categorical_accuracy: 0.9495
# Epoch 10/40
# 41/41 [==============================] - 3s 60ms/step - loss: 0.1585 - sparse_categorical_accuracy: 0.9495
# Epoch 11/40
# 41/41 [==============================] - 2s 56ms/step - loss: 0.1429 - sparse_categorical_accuracy: 0.9554
# Epoch 12/40
# 41/41 [==============================] - 3s 69ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9554
# Epoch 13/40
# 41/41 [==============================] - 3s 59ms/step - loss: 0.1493 - sparse_categorical_accuracy: 0.9470
# Epoch 14/40
# 41/41 [==============================] - 3s 69ms/step - loss: 0.1448 - sparse_categorical_accuracy: 0.9505
# Epoch 15/40
# 41/41 [==============================] - 3s 68ms/step - loss: 0.1359 - sparse_categorical_accuracy: 0.9559
# Epoch 16/40
# 41/41 [==============================] - 3s 58ms/step - loss: 0.1445 - sparse_categorical_accuracy: 0.9515
# Epoch 17/40
# 41/41 [==============================] - 2s 58ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9549
# Epoch 18/40
# 41/41 [==============================] - 3s 64ms/step - loss: 0.1391 - sparse_categorical_accuracy: 0.9584
# Epoch 19/40
# 41/41 [==============================] - 2s 57ms/step - loss: 0.1403 - sparse_categorical_accuracy: 0.9510
# Epoch 20/40
# 41/41 [==============================] - 3s 63ms/step - loss: 0.1364 - sparse_categorical_accuracy: 0.9544
# Epoch 21/40
# 41/41 [==============================] - 3s 62ms/step - loss: 0.1190 - sparse_categorical_accuracy: 0.9604
# Epoch 22/40
# 41/41 [==============================] - 3s 67ms/step - loss: 0.1335 - sparse_categorical_accuracy: 0.9574
# Epoch 23/40
# 41/41 [==============================] - 3s 60ms/step - loss: 0.1226 - sparse_categorical_accuracy: 0.9609
# Epoch 24/40
# 41/41 [==============================] - 3s 63ms/step - loss: 0.1071 - sparse_categorical_accuracy: 0.9619
# Epoch 25/40
# 41/41 [==============================] - 2s 58ms/step - loss: 0.1295 - sparse_categorical_accuracy: 0.9589
# Epoch 26/40
# 41/41 [==============================] - 3s 61ms/step - loss: 0.1138 - sparse_categorical_accuracy: 0.9658
# Epoch 27/40
# 41/41 [==============================] - 3s 61ms/step - loss: 0.1302 - sparse_categorical_accuracy: 0.9589
# Epoch 28/40
# 41/41 [==============================] - 3s 58ms/step - loss: 0.1261 - sparse_categorical_accuracy: 0.9594
# Epoch 29/40
# 41/41 [==============================] - 3s 59ms/step - loss: 0.1245 - sparse_categorical_accuracy: 0.9579
# Epoch 30/40
# 41/41 [==============================] - 3s 62ms/step - loss: 0.1333 - sparse_categorical_accuracy: 0.9584
# Epoch 31/40
# 41/41 [==============================] - 3s 66ms/step - loss: 0.1281 - sparse_categorical_accuracy: 0.9569
# Epoch 32/40
# 41/41 [==============================] - 3s 59ms/step - loss: 0.1240 - sparse_categorical_accuracy: 0.9579
# Epoch 33/40
# 41/41 [==============================] - 2s 58ms/step - loss: 0.1056 - sparse_categorical_accuracy: 0.9653
# Epoch 34/40
# 41/41 [==============================] - 2s 57ms/step - loss: 0.1206 - sparse_categorical_accuracy: 0.9609
# Epoch 35/40
# 41/41 [==============================] - 3s 62ms/step - loss: 0.1101 - sparse_categorical_accuracy: 0.9673
# Epoch 36/40
# 41/41 [==============================] - 3s 59ms/step - loss: 0.1154 - sparse_categorical_accuracy: 0.9619
# Epoch 37/40
# 41/41 [==============================] - 2s 58ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9619
# Epoch 38/40
# 41/41 [==============================] - 3s 61ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9604
# Epoch 39/40
# 41/41 [==============================] - 3s 65ms/step - loss: 0.1055 - sparse_categorical_accuracy: 0.9638
# Epoch 40/40
# 41/41 [==============================] - 2s 58ms/step - loss: 0.1109 - sparse_categorical_accuracy: 0.9648
# 11/11 [==============================] - 1s 26ms/step - loss: 0.7006 - sparse_categorical_accuracy: 0.8248
# Test accuracy: 82.48%

# %%
plt.plot(history1.history['sparse_categorical_accuracy'])
plt.plot(history.history['sparse_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training with SCL','training without SCL'], loc='lower right')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
# Pillow
import PIL
from PIL import Image,ImageEnhance,ImageFilter

import numpy as np
import matplotlib.pyplot as plt
import glob, os
import re
import numpy
import pathlib as Path
import os.path
from os import path
import shutil
from random import randrange, uniform

# %%
shutil.rmtree('/Colab-Notebooks/Aug_Test/', ignore_errors=True)

# %%
if path.isdir('/Colab-Notebooks/Aug_Test/'):
  print('Path exists.....skipping')
else:
  os.mkdir('/Colab-Notebooks/Aug_Test/')

# %%
import cv2
import os
from PIL import ImageFilter

def load_images_from_folder(folder,class_names):
    global data
    data = []
    for subdir, dirs, files in os.walk(folder):
      for file in files:
        img = Image.open(os.path.join(subdir, file)).convert('RGB')
        img = img.resize((180, 180))
        #Random Generator
        x = uniform(0.2, 1.8)#where 0 is black and 2 is white
        #Preprocessing-Random Brightness
        color_enhancer = ImageEnhance.Brightness(img)
        img_EN = color_enhancer.enhance(x)

        #im_Ed = color_enhancer.enhance(.4)
        #data.extend([img_EN,im_Ed])
        open_cv_img = numpy.array(img)
        open_cv_img_en = numpy.array(img_EN)
        #open_cv_img_ed = numpy.array(im_Ed)
        open_cv_img = cv2.cvtColor(open_cv_img, cv2.COLOR_RGB2BGR)
        open_cv_img_en = cv2.cvtColor(open_cv_img_en, cv2.COLOR_RGB2BGR)
        #open_cv_img_ed = cv2.cvtColor(open_cv_img_ed, cv2.COLOR_RGB2BGR)
        data.extend([open_cv_img,open_cv_img_en])
          # Convert RGB to BGR 
        for a in range (0,(len(data))):
            #data[a].save(save_path /  str(count)+'.jpg')
            #path = os.path.join('/Colab-Notebooks/Aug_Test/',class_names)
            base_path = '/Colab-Notebooks/Aug_Test/'
            if path.isdir(os.path.join(base_path,class_names)):
              cv2.imwrite(base_path + class_names + f'/image_{a}.png',data[a])
            else:
              os.mkdir(os.path.join(base_path,class_names))
              cv2.imwrite(base_path + class_names + f'/image_{a}.png',data[a])
            #print(path + f'/image_{a}.png')
            #cv2.imwrite(f'/Colab-Notebooks/Test3/image_{a}.png',data[a])

    return

# %%
 #data.extend([img_EN,im_Ed])

# %%
#@title Default title text
load_images_from_folder("/Colab-Notebooks/Split/train/cardboard",'cardboard')

# %%
load_images_from_folder("/Colab-Notebooks/Split/train/glass",'glass')

# %%
load_images_from_folder("/Colab-Notebooks/Split/train/metal",'metal')

# %%
load_images_from_folder("/Colab-Notebooks/Split/train/paper",'paper')

# %%
load_images_from_folder("/Colab-Notebooks/Split/train/trash",'trash')

# %%
load_images_from_folder("/Colab-Notebooks/Split/train/plastic",'plastic')

# %%
Test = '/Colab-Notebooks/Aug_Test/'

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    Test,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    image_size=(180,180),
    batch_size=32,
    shuffle=True,
    seed=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 4038 files belonging to 6 classes.

# %%
encoder = create_encoder()

encoder_with_projection_head = add_projection_head(encoder)
encoder_with_projection_head.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=SupervisedContrastiveLoss(temperature),
)

encoder_with_projection_head.summary()

history_mod_loss = encoder_with_projection_head.fit(
    train_ds, batch_size=batch_size, epochs=num_epochs
)
# Out:
# Model: "encoder_with_projection-head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 180, 180, 3)]     0
#
#  Xcept-encoder (Functional)  (None, 2048)              20861487
#
#  dense_5 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 21,123,759
# Trainable params: 21,069,224
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/40
# 127/127 [==============================] - 74s 543ms/step - loss: 3.2151
# Epoch 2/40
# 127/127 [==============================] - 55s 434ms/step - loss: 3.1155
# Epoch 3/40
# 127/127 [==============================] - 49s 385ms/step - loss: 3.0498
# Epoch 4/40
# 127/127 [==============================] - 48s 376ms/step - loss: 2.9897
# Epoch 5/40
# 127/127 [==============================] - 45s 354ms/step - loss: 2.9371
# Epoch 6/40
# 127/127 [==============================] - 44s 344ms/step - loss: 2.9120
# Epoch 7/40
# 127/127 [==============================] - 41s 325ms/step - loss: 2.8684
# Epoch 8/40
# 127/127 [==============================] - 39s 310ms/step - loss: 2.8108
# Epoch 9/40
# 127/127 [==============================] - 38s 299ms/step - loss: 2.7621
# Epoch 10/40
# 127/127 [==============================] - 37s 290ms/step - loss: 2.7334
# Epoch 11/40
# 127/127 [==============================] - 35s 273ms/step - loss: 2.6976
# Epoch 12/40
# 127/127 [==============================] - 34s 269ms/step - loss: 2.6766
# Epoch 13/40
# 127/127 [==============================] - 32s 252ms/step - loss: 2.6230
# Epoch 14/40
# 127/127 [==============================] - 34s 266ms/step - loss: 2.6195
# Epoch 15/40
# 127/127 [==============================] - 31s 246ms/step - loss: 2.5877
# Epoch 16/40
# 127/127 [==============================] - 31s 242ms/step - loss: 2.5594
# Epoch 17/40
# 127/127 [==============================] - 32s 252ms/step - loss: 2.5102
# Epoch 18/40
# 127/127 [==============================] - 30s 236ms/step - loss: 2.4932
# Epoch 19/40
# 127/127 [==============================] - 30s 235ms/step - loss: 2.4536
# Epoch 20/40
# 127/127 [==============================] - 28s 221ms/step - loss: 2.4341
# Epoch 21/40
# 127/127 [==============================] - 28s 219ms/step - loss: 2.3963
# Epoch 22/40
# 127/127 [==============================] - 28s 217ms/step - loss: 2.3784
# Epoch 23/40
# 127/127 [==============================] - 28s 223ms/step - loss: 2.3875
# Epoch 24/40
# 127/127 [==============================] - 28s 221ms/step - loss: 2.3457
# Epoch 25/40
# 127/127 [==============================] - 29s 224ms/step - loss: 2.3401
# Epoch 26/40
# 127/127 [==============================] - 27s 212ms/step - loss: 2.2945
# Epoch 27/40
# 127/127 [==============================] - 27s 214ms/step - loss: 2.2696
# Epoch 28/40
# 127/127 [==============================] - 30s 233ms/step - loss: 2.2719
# Epoch 29/40
# 127/127 [==============================] - 28s 217ms/step - loss: 2.2536
# Epoch 30/40
# 127/127 [==============================] - 26s 208ms/step - loss: 2.2216
# Epoch 31/40
# 127/127 [==============================] - 26s 205ms/step - loss: 2.2167
# Epoch 32/40
# 127/127 [==============================] - 26s 206ms/step - loss: 2.2089
# Epoch 33/40
# 127/127 [==============================] - 25s 200ms/step - loss: 2.1789
# Epoch 34/40
# 127/127 [==============================] - 26s 205ms/step - loss: 2.2005
# Epoch 35/40
# 127/127 [==============================] - 26s 207ms/step - loss: 2.1388
# Epoch 36/40
# 127/127 [==============================] - 26s 205ms/step - loss: 2.1552
# Epoch 37/40
# 127/127 [==============================] - 25s 198ms/step - loss: 2.1648
# Epoch 38/40
# 127/127 [==============================] - 25s 198ms/step - loss: 2.1376
# Epoch 39/40
# 127/127 [==============================] - 25s 195ms/step - loss: 2.1392
# Epoch 40/40
# 127/127 [==============================] - 26s 202ms/step - loss: 2.1218

# %%
plt.plot(history_mod_loss.history['loss'])
plt.plot(history1_Loss.history['loss'])
#plt.plot(history1.history['sparse_categorical_accuracy'])
#plt.plot(history.history['val_acc'])
plt.title('Training Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['training loss RandBrightness.','training loss without Aug.' ], loc='upper right')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
classifier = create_classifier(encoder, trainable=False)

history_mod = classifier.fit(train_ds, batch_size=batch_size, epochs=num_epochs)
# Out:
# Epoch 1/40
# 127/127 [==============================] - 8s 40ms/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8767
# Epoch 2/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.2543 - sparse_categorical_accuracy: 0.9118
# Epoch 3/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.2368 - sparse_categorical_accuracy: 0.9222
# Epoch 4/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.2329 - sparse_categorical_accuracy: 0.9237
# Epoch 5/40
# 127/127 [==============================] - 5s 41ms/step - loss: 0.2245 - sparse_categorical_accuracy: 0.9272
# Epoch 6/40
# 127/127 [==============================] - 5s 40ms/step - loss: 0.2227 - sparse_categorical_accuracy: 0.9274
# Epoch 7/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.2065 - sparse_categorical_accuracy: 0.9297
# Epoch 8/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.2045 - sparse_categorical_accuracy: 0.9331
# Epoch 9/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.2097 - sparse_categorical_accuracy: 0.9282
# Epoch 10/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.2080 - sparse_categorical_accuracy: 0.9255
# Epoch 11/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1987 - sparse_categorical_accuracy: 0.9354
# Epoch 12/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1871 - sparse_categorical_accuracy: 0.9368
# Epoch 13/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.1940 - sparse_categorical_accuracy: 0.9366
# Epoch 14/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1824 - sparse_categorical_accuracy: 0.9421
# Epoch 15/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.1835 - sparse_categorical_accuracy: 0.9378
# Epoch 16/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.1848 - sparse_categorical_accuracy: 0.9359
# Epoch 17/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.1820 - sparse_categorical_accuracy: 0.9398
# Epoch 18/40
# 127/127 [==============================] - 5s 40ms/step - loss: 0.1795 - sparse_categorical_accuracy: 0.9386
# Epoch 19/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.1736 - sparse_categorical_accuracy: 0.9391
# Epoch 20/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1734 - sparse_categorical_accuracy: 0.9421
# Epoch 21/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1685 - sparse_categorical_accuracy: 0.9435
# Epoch 22/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1882 - sparse_categorical_accuracy: 0.9336
# Epoch 23/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1776 - sparse_categorical_accuracy: 0.9406
# Epoch 24/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1649 - sparse_categorical_accuracy: 0.9450
# Epoch 25/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1670 - sparse_categorical_accuracy: 0.9413
# Epoch 26/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1706 - sparse_categorical_accuracy: 0.9435
# Epoch 27/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1611 - sparse_categorical_accuracy: 0.9418
# Epoch 28/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1696 - sparse_categorical_accuracy: 0.9401
# Epoch 29/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1697 - sparse_categorical_accuracy: 0.9406
# Epoch 30/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1716 - sparse_categorical_accuracy: 0.9411
# Epoch 31/40
# 127/127 [==============================] - 5s 39ms/step - loss: 0.1620 - sparse_categorical_accuracy: 0.9403
# Epoch 32/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1651 - sparse_categorical_accuracy: 0.9391
# Epoch 33/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1734 - sparse_categorical_accuracy: 0.9366
# Epoch 34/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1723 - sparse_categorical_accuracy: 0.9403
# Epoch 35/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1662 - sparse_categorical_accuracy: 0.9433
# Epoch 36/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1624 - sparse_categorical_accuracy: 0.9450
# Epoch 37/40
# 127/127 [==============================] - 5s 38ms/step - loss: 0.1618 - sparse_categorical_accuracy: 0.9468
# Epoch 38/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1567 - sparse_categorical_accuracy: 0.9460
# Epoch 39/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1677 - sparse_categorical_accuracy: 0.9393
# Epoch 40/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1744 - sparse_categorical_accuracy: 0.9396

# %%
accuracy = classifier.evaluate(val_ds)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 11/11 [==============================] - 1s 26ms/step - loss: 0.6472 - sparse_categorical_accuracy: 0.7992
# Test accuracy: 79.92%

# %%
plt.plot(history_mod.history['sparse_categorical_accuracy'])
plt.plot(history1.history['sparse_categorical_accuracy'])
plt.plot(history.history['sparse_categorical_accuracy'])
plt.title('training model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training with SCL-RandBrightness.','training with SCL','training without SCL'], loc='lower right')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
shutil.rmtree('/Colab-Notebooks/Augc_Test/', ignore_errors=True)

# %%
if path.isdir('/Colab-Notebooks/Augc_Test/'):
  print('Path exists.....skipping')
else:
  os.mkdir('/Colab-Notebooks/Augc_Test/')

# %%
import cv2
import os
from PIL import ImageFilter

def load_images_from_folder(folder,class_names):
    global data
    data = []
    for subdir, dirs, files in os.walk(folder):
      for file in files:
        img = Image.open(os.path.join(subdir, file)).convert('RGB')
        img = img.resize((180, 180))
        #Random Generator
        x = uniform(0.0, 1.0)
        #Preprocessing-Random Contrast
        color_enhancer = ImageEnhance.Contrast(img)
        img_EN = color_enhancer.enhance(x)

        #im_Ed = color_enhancer.enhance(.4)
        #data.extend([img_EN,im_Ed])
        open_cv_img = numpy.array(img)
        open_cv_img_en = numpy.array(img_EN)
        #open_cv_img_ed = numpy.array(im_Ed)
        open_cv_img = cv2.cvtColor(open_cv_img, cv2.COLOR_RGB2BGR)
        open_cv_img_en = cv2.cvtColor(open_cv_img_en, cv2.COLOR_RGB2BGR)
        #open_cv_img_ed = cv2.cvtColor(open_cv_img_ed, cv2.COLOR_RGB2BGR)
        data.extend([open_cv_img,open_cv_img_en])
          # Convert RGB to BGR 
        for a in range (0,(len(data))):
            #data[a].save(save_path /  str(count)+'.jpg')
            #path = os.path.join('/Colab-Notebooks/Aug_Test/',class_names)
            base_path = '/Colab-Notebooks/Augc_Test/'
            if path.isdir(os.path.join(base_path,class_names)):
              cv2.imwrite(base_path + class_names + f'/image_{a}.png',data[a])
            else:
              os.mkdir(os.path.join(base_path,class_names))
              cv2.imwrite(base_path + class_names + f'/image_{a}.png',data[a])
            #print(path + f'/image_{a}.png')
            #cv2.imwrite(f'/Colab-Notebooks/Test3/image_{a}.png',data[a])

    return

# %%
load_images_from_folder("/Colab-Notebooks/Split/train/cardboard",'cardboard')
load_images_from_folder("/Colab-Notebooks/Split/train/glass",'glass')
load_images_from_folder("/Colab-Notebooks/Split/train/metal",'metal')
load_images_from_folder("/Colab-Notebooks/Split/train/paper",'paper')
load_images_from_folder("/Colab-Notebooks/Split/train/trash",'trash')
load_images_from_folder("/Colab-Notebooks/Split/train/plastic",'plastic')

# %%
Test1 = '/Colab-Notebooks/Augc_Test/'

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    Test1,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    image_size=(180,180),
    batch_size=32,
    shuffle=True,
    seed=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 4038 files belonging to 6 classes.

# %%
encoder = create_encoder()

encoder_with_projection_head = add_projection_head(encoder)
encoder_with_projection_head.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=SupervisedContrastiveLoss(temperature),
)

encoder_with_projection_head.summary()

history_mod_loss1 = encoder_with_projection_head.fit(
    train_ds, batch_size=batch_size, epochs=num_epochs
)
# Out:
# Model: "encoder_with_projection-head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 180, 180, 3)]     0
#
#  Xcept-encoder (Functional)  (None, 2048)              20861487
#
#  dense_8 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 21,123,759
# Trainable params: 21,069,224
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/40
# 127/127 [==============================] - 31s 208ms/step - loss: 3.2480
# Epoch 2/40
# 127/127 [==============================] - 28s 220ms/step - loss: 3.1301
# Epoch 3/40
# 127/127 [==============================] - 27s 209ms/step - loss: 3.0678
# Epoch 4/40
# 127/127 [==============================] - 26s 208ms/step - loss: 3.0239
# Epoch 5/40
# 127/127 [==============================] - 25s 193ms/step - loss: 2.9739
# Epoch 6/40
# 127/127 [==============================] - 25s 197ms/step - loss: 2.9305
# Epoch 7/40
# 127/127 [==============================] - 26s 205ms/step - loss: 2.9087
# Epoch 8/40
# 127/127 [==============================] - 25s 198ms/step - loss: 2.8364
# Epoch 9/40
# 127/127 [==============================] - 25s 200ms/step - loss: 2.8194
# Epoch 10/40
# 127/127 [==============================] - 25s 196ms/step - loss: 2.7805
# Epoch 11/40
# 127/127 [==============================] - 25s 199ms/step - loss: 2.7565
# Epoch 12/40
# 127/127 [==============================] - 25s 198ms/step - loss: 2.7316
# Epoch 13/40
# 127/127 [==============================] - 26s 200ms/step - loss: 2.6898
# Epoch 14/40
# 127/127 [==============================] - 25s 199ms/step - loss: 2.6557
# Epoch 15/40
# 127/127 [==============================] - 25s 196ms/step - loss: 2.6321
# Epoch 16/40
# 127/127 [==============================] - 25s 197ms/step - loss: 2.6143
# Epoch 17/40
# 127/127 [==============================] - 26s 204ms/step - loss: 2.5978
# Epoch 18/40
# 127/127 [==============================] - 25s 194ms/step - loss: 2.5381
# Epoch 19/40
# 127/127 [==============================] - 26s 200ms/step - loss: 2.5202
# Epoch 20/40
# 127/127 [==============================] - 25s 200ms/step - loss: 2.4966
# Epoch 21/40
# 127/127 [==============================] - 26s 202ms/step - loss: 2.4887
# Epoch 22/40
# 127/127 [==============================] - 25s 200ms/step - loss: 2.4729
# Epoch 23/40
# 127/127 [==============================] - 25s 199ms/step - loss: 2.4599
# Epoch 24/40
# 127/127 [==============================] - 25s 200ms/step - loss: 2.4049
# Epoch 25/40
# 127/127 [==============================] - 26s 202ms/step - loss: 2.4066
# Epoch 26/40
# 127/127 [==============================] - 26s 203ms/step - loss: 2.3656
# Epoch 27/40
# 127/127 [==============================] - 25s 199ms/step - loss: 2.3754
# Epoch 28/40
# 127/127 [==============================] - 25s 194ms/step - loss: 2.3263
# Epoch 29/40
# 127/127 [==============================] - 26s 207ms/step - loss: 2.3305
# Epoch 30/40
# 127/127 [==============================] - 26s 202ms/step - loss: 2.3048
# Epoch 31/40
# 127/127 [==============================] - 25s 198ms/step - loss: 2.3095
# Epoch 32/40
# 127/127 [==============================] - 26s 208ms/step - loss: 2.2989
# Epoch 33/40
# 127/127 [==============================] - 26s 203ms/step - loss: 2.2671
# Epoch 34/40
# 127/127 [==============================] - 25s 198ms/step - loss: 2.2433
# Epoch 35/40
# 127/127 [==============================] - 25s 196ms/step - loss: 2.2302
# Epoch 36/40
# 127/127 [==============================] - 25s 196ms/step - loss: 2.2120
# Epoch 37/40
# 127/127 [==============================] - 25s 199ms/step - loss: 2.2237
# Epoch 38/40
# 127/127 [==============================] - 25s 196ms/step - loss: 2.2462
# Epoch 39/40
# 127/127 [==============================] - 25s 195ms/step - loss: 2.2024
# Epoch 40/40
# 127/127 [==============================] - 25s 197ms/step - loss: 2.1915

# %%
plt.plot(history_mod_loss.history['loss'])
plt.plot(history_mod_loss1.history['loss'])
plt.plot(history1_Loss.history['loss'])
#plt.plot(history1.history['sparse_categorical_accuracy'])
#plt.plot(history.history['val_acc'])
plt.title('Training Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['training loss RandBrightness.','training loss RandContrast','training loss without Aug.' ], loc='upper right')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
classifier = create_classifier(encoder, trainable=False)

history_mod1 = classifier.fit(train_ds, batch_size=batch_size, epochs=num_epochs)

accuracy = classifier.evaluate(val_ds)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# Epoch 1/40
# 127/127 [==============================] - 8s 36ms/step - loss: 0.4057 - sparse_categorical_accuracy: 0.8742
# Epoch 2/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2718 - sparse_categorical_accuracy: 0.9118
# Epoch 3/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2679 - sparse_categorical_accuracy: 0.9118
# Epoch 4/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.2572 - sparse_categorical_accuracy: 0.9131
# Epoch 5/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2478 - sparse_categorical_accuracy: 0.9195
# Epoch 6/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2223 - sparse_categorical_accuracy: 0.9252
# Epoch 7/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.2294 - sparse_categorical_accuracy: 0.9210
# Epoch 8/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2351 - sparse_categorical_accuracy: 0.9188
# Epoch 9/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.2392 - sparse_categorical_accuracy: 0.9210
# Epoch 10/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2222 - sparse_categorical_accuracy: 0.9250
# Epoch 11/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2278 - sparse_categorical_accuracy: 0.9264
# Epoch 12/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2210 - sparse_categorical_accuracy: 0.9257
# Epoch 13/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2239 - sparse_categorical_accuracy: 0.9198
# Epoch 14/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2077 - sparse_categorical_accuracy: 0.9331
# Epoch 15/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2126 - sparse_categorical_accuracy: 0.9277
# Epoch 16/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2253 - sparse_categorical_accuracy: 0.9257
# Epoch 17/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2110 - sparse_categorical_accuracy: 0.9304
# Epoch 18/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2127 - sparse_categorical_accuracy: 0.9282
# Epoch 19/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2076 - sparse_categorical_accuracy: 0.9289
# Epoch 20/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1999 - sparse_categorical_accuracy: 0.9334
# Epoch 21/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2089 - sparse_categorical_accuracy: 0.9294
# Epoch 22/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2042 - sparse_categorical_accuracy: 0.9324
# Epoch 23/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2047 - sparse_categorical_accuracy: 0.9304
# Epoch 24/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1954 - sparse_categorical_accuracy: 0.9331
# Epoch 25/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1947 - sparse_categorical_accuracy: 0.9292
# Epoch 26/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2129 - sparse_categorical_accuracy: 0.9279
# Epoch 27/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2071 - sparse_categorical_accuracy: 0.9252
# Epoch 28/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1939 - sparse_categorical_accuracy: 0.9334
# Epoch 29/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1975 - sparse_categorical_accuracy: 0.9321
# Epoch 30/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1883 - sparse_categorical_accuracy: 0.9316
# Epoch 31/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1769 - sparse_categorical_accuracy: 0.9391
# Epoch 32/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1919 - sparse_categorical_accuracy: 0.9339
# Epoch 33/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1963 - sparse_categorical_accuracy: 0.9368
# Epoch 34/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2112 - sparse_categorical_accuracy: 0.9294
# Epoch 35/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1766 - sparse_categorical_accuracy: 0.9381
# Epoch 36/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.2052 - sparse_categorical_accuracy: 0.9292
# Epoch 37/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1759 - sparse_categorical_accuracy: 0.9411
# Epoch 38/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.9329
# Epoch 39/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.1880 - sparse_categorical_accuracy: 0.9371
# Epoch 40/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.1925 - sparse_categorical_accuracy: 0.9393
# 11/11 [==============================] - 1s 25ms/step - loss: 0.7141 - sparse_categorical_accuracy: 0.8268
# Test accuracy: 82.68%

# %%
accuracy = classifier.evaluate(val_ds)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 11/11 [==============================] - 0s 26ms/step - loss: 0.7141 - sparse_categorical_accuracy: 0.8268
# Test accuracy: 82.68%

# %%
plt.plot(history_mod.history['sparse_categorical_accuracy'])
plt.plot(history_mod1.history['sparse_categorical_accuracy'])
#plt.plot(history_mod2.history['sparse_categorical_accuracy'])
plt.plot(history1.history['sparse_categorical_accuracy'])
plt.plot(history.history['sparse_categorical_accuracy'])
plt.title('training model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training with SCL-RandBrightness.','training with SCL-RandContrast','training with SCL','training without SCL'], loc='lower right')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
shutil.rmtree('/Colab-Notebooks/Augb_Test/', ignore_errors=True)

# %%
if path.isdir('/Colab-Notebooks/Augb_Test/'):
  print('Path exists.....skipping')
else:
  os.mkdir('/Colab-Notebooks/Augb_Test/')

# %%
import cv2
import os
from PIL import ImageFilter

def load_images_from_folder(folder,class_names):
    global data
    data = []
    for subdir, dirs, files in os.walk(folder):
      for file in files:
        img = Image.open(os.path.join(subdir, file)).convert('RGB')
        img = img.resize((180, 180))
        #Random Generator
        x = uniform(0.0, 2.0)
        #Preprocessing-Random Contrast
        color_enhancer = ImageEnhance.Sharpness(img)
        img_EN = color_enhancer.enhance(x)

        #im_Ed = color_enhancer.enhance(.4)
        #data.extend([img_EN,im_Ed])
        open_cv_img = numpy.array(img)
        open_cv_img_en = numpy.array(img_EN)
        #open_cv_img_ed = numpy.array(im_Ed)
        open_cv_img = cv2.cvtColor(open_cv_img, cv2.COLOR_RGB2BGR)
        open_cv_img_en = cv2.cvtColor(open_cv_img_en, cv2.COLOR_RGB2BGR)
        #open_cv_img_ed = cv2.cvtColor(open_cv_img_ed, cv2.COLOR_RGB2BGR)
        data.extend([open_cv_img,open_cv_img_en])
          # Convert RGB to BGR 
        for a in range (0,(len(data))):
            #data[a].save(save_path /  str(count)+'.jpg')
            #path = os.path.join('/Colab-Notebooks/Aug_Test/',class_names)
            base_path = '/Colab-Notebooks/Augb_Test/'
            if path.isdir(os.path.join(base_path,class_names)):
              cv2.imwrite(base_path + class_names + f'/image_{a}.png',data[a])
            else:
              os.mkdir(os.path.join(base_path,class_names))
              cv2.imwrite(base_path + class_names + f'/image_{a}.png',data[a])
            #print(path + f'/image_{a}.png')
            #cv2.imwrite(f'/Colab-Notebooks/Test3/image_{a}.png',data[a])

    return

# %%
load_images_from_folder("/Colab-Notebooks/Split/train/cardboard",'cardboard')
load_images_from_folder("/Colab-Notebooks/Split/train/glass",'glass')
load_images_from_folder("/Colab-Notebooks/Split/train/metal",'metal')
load_images_from_folder("/Colab-Notebooks/Split/train/paper",'paper')
load_images_from_folder("/Colab-Notebooks/Split/train/trash",'trash')
load_images_from_folder("/Colab-Notebooks/Split/train/plastic",'plastic')

# %%
Test2 = '/Colab-Notebooks/Augb_Test/'

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    Test2,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    image_size=(180,180),
    batch_size=32,
    shuffle=True,
    seed=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,)
# Out:
# Found 4038 files belonging to 6 classes.

# %%
encoder = create_encoder()

encoder_with_projection_head = add_projection_head(encoder)
encoder_with_projection_head.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=SupervisedContrastiveLoss(temperature),
)

encoder_with_projection_head.summary()

history_mod_loss2 = encoder_with_projection_head.fit(
    train_ds, batch_size=batch_size, epochs=num_epochs
)
# Out:
# Model: "encoder_with_projection-head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 180, 180, 3)]     0
#
#  Xcept-encoder (Functional)  (None, 2048)              20861487
#
#  dense_11 (Dense)            (None, 128)               262272
#
# =================================================================
# Total params: 21,123,759
# Trainable params: 21,069,224
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/40
# 127/127 [==============================] - 31s 204ms/step - loss: 3.1255
# Epoch 2/40
# 127/127 [==============================] - 25s 200ms/step - loss: 2.9427
# Epoch 3/40
# 127/127 [==============================] - 25s 199ms/step - loss: 2.8574
# Epoch 4/40
# 127/127 [==============================] - 25s 197ms/step - loss: 2.7636
# Epoch 5/40
# 127/127 [==============================] - 25s 194ms/step - loss: 2.7305
# Epoch 6/40
# 127/127 [==============================] - 25s 199ms/step - loss: 2.6568
# Epoch 7/40
# 127/127 [==============================] - 25s 192ms/step - loss: 2.5986
# Epoch 8/40
# 127/127 [==============================] - 25s 194ms/step - loss: 2.5586
# Epoch 9/40
# 127/127 [==============================] - 25s 195ms/step - loss: 2.5152
# Epoch 10/40
# 127/127 [==============================] - 25s 193ms/step - loss: 2.4496
# Epoch 11/40
# 127/127 [==============================] - 26s 202ms/step - loss: 2.4116
# Epoch 12/40
# 127/127 [==============================] - 24s 190ms/step - loss: 2.3904
# Epoch 13/40
# 127/127 [==============================] - 26s 201ms/step - loss: 2.3704
# Epoch 14/40
# 127/127 [==============================] - 24s 190ms/step - loss: 2.3105
# Epoch 15/40
# 127/127 [==============================] - 26s 204ms/step - loss: 2.3293
# Epoch 16/40
# 127/127 [==============================] - 25s 200ms/step - loss: 2.2790
# Epoch 17/40
# 127/127 [==============================] - 26s 203ms/step - loss: 2.2342
# Epoch 18/40
# 127/127 [==============================] - 25s 194ms/step - loss: 2.2329
# Epoch 19/40
# 127/127 [==============================] - 26s 204ms/step - loss: 2.1882
# Epoch 20/40
# 127/127 [==============================] - 25s 196ms/step - loss: 2.1807
# Epoch 21/40
# 127/127 [==============================] - 26s 205ms/step - loss: 2.1548
# Epoch 22/40
# 127/127 [==============================] - 24s 192ms/step - loss: 2.1616
# Epoch 23/40
# 127/127 [==============================] - 25s 198ms/step - loss: 2.1318
# Epoch 24/40
# 127/127 [==============================] - 25s 195ms/step - loss: 2.1234
# Epoch 25/40
# 127/127 [==============================] - 25s 195ms/step - loss: 2.1044
# Epoch 26/40
# 127/127 [==============================] - 25s 193ms/step - loss: 2.0651
# Epoch 27/40
# 127/127 [==============================] - 25s 194ms/step - loss: 2.0829
# Epoch 28/40
# 127/127 [==============================] - 25s 193ms/step - loss: 2.0772
# Epoch 29/40
# 127/127 [==============================] - 24s 191ms/step - loss: 2.0595
# Epoch 30/40
# 127/127 [==============================] - 25s 195ms/step - loss: 2.0486
# Epoch 31/40
# 127/127 [==============================] - 25s 197ms/step - loss: 2.0390
# Epoch 32/40
# 127/127 [==============================] - 24s 192ms/step - loss: 2.0365
# Epoch 33/40
# 127/127 [==============================] - 25s 193ms/step - loss: 2.0096
# Epoch 34/40
# 127/127 [==============================] - 26s 203ms/step - loss: 2.0164
# Epoch 35/40
# 127/127 [==============================] - 24s 189ms/step - loss: 2.0112
# Epoch 36/40
# 127/127 [==============================] - 24s 190ms/step - loss: 1.9981
# Epoch 37/40
# 127/127 [==============================] - 25s 196ms/step - loss: 1.9946
# Epoch 38/40
# 127/127 [==============================] - 25s 192ms/step - loss: 1.9940
# Epoch 39/40
# 127/127 [==============================] - 24s 192ms/step - loss: 1.9829
# Epoch 40/40
# 127/127 [==============================] - 25s 194ms/step - loss: 2.0038

# %%
plt.plot(history_mod_loss.history['loss'])
plt.plot(history_mod_loss1.history['loss'])
plt.plot(history_mod_loss2.history['loss'])
plt.plot(history1_Loss.history['loss'])
#plt.plot(history1.history['sparse_categorical_accuracy'])
#plt.plot(history.history['val_acc'])
plt.title('Training Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['training loss RandBrightness','training loss RandContrast','training loss RandSharpness','training loss without Aug.' ], loc='upper right')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
classifier = create_classifier(encoder, trainable=False)

history_mod2 = classifier.fit(train_ds, batch_size=batch_size, epochs=num_epochs)

accuracy = classifier.evaluate(val_ds)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# Epoch 1/40
# 127/127 [==============================] - 7s 36ms/step - loss: 0.2163 - sparse_categorical_accuracy: 0.9292
# Epoch 2/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0952 - sparse_categorical_accuracy: 0.9708
# Epoch 3/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0891 - sparse_categorical_accuracy: 0.9725
# Epoch 4/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9765
# Epoch 5/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9782
# Epoch 6/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9755
# Epoch 7/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0647 - sparse_categorical_accuracy: 0.9809
# Epoch 8/40
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0745 - sparse_categorical_accuracy: 0.9728
# Epoch 9/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0731 - sparse_categorical_accuracy: 0.9775
# Epoch 10/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0740 - sparse_categorical_accuracy: 0.9760
# Epoch 11/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9782
# Epoch 12/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0565 - sparse_categorical_accuracy: 0.9807
# Epoch 13/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9760
# Epoch 14/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9762
# Epoch 15/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0616 - sparse_categorical_accuracy: 0.9792
# Epoch 16/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0546 - sparse_categorical_accuracy: 0.9809
# Epoch 17/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0634 - sparse_categorical_accuracy: 0.9792
# Epoch 18/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0570 - sparse_categorical_accuracy: 0.9817
# Epoch 19/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9817
# Epoch 20/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9824
# Epoch 21/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0579 - sparse_categorical_accuracy: 0.9817
# Epoch 22/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0532 - sparse_categorical_accuracy: 0.9844
# Epoch 23/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9839
# Epoch 24/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9844
# Epoch 25/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9837
# Epoch 26/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0544 - sparse_categorical_accuracy: 0.9864
# Epoch 27/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9849
# Epoch 28/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9849
# Epoch 29/40
# 127/127 [==============================] - 4s 35ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9829
# Epoch 30/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9846
# Epoch 31/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0505 - sparse_categorical_accuracy: 0.9837
# Epoch 32/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0475 - sparse_categorical_accuracy: 0.9837
# Epoch 33/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9809
# Epoch 34/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9869
# Epoch 35/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9849
# Epoch 36/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0462 - sparse_categorical_accuracy: 0.9832
# Epoch 37/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0408 - sparse_categorical_accuracy: 0.9851
# Epoch 38/40
# 127/127 [==============================] - 5s 35ms/step - loss: 0.0472 - sparse_categorical_accuracy: 0.9846
# Epoch 39/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9871
# Epoch 40/40
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0525 - sparse_categorical_accuracy: 0.9827
# 11/11 [==============================] - 1s 25ms/step - loss: 0.7456 - sparse_categorical_accuracy: 0.8504
# Test accuracy: 85.04%

# %%
plt.plot(history_mod.history['sparse_categorical_accuracy'])
plt.plot(history_mod1.history['sparse_categorical_accuracy'])
plt.plot(history_mod2.history['sparse_categorical_accuracy'])
plt.plot(history1.history['sparse_categorical_accuracy'])
plt.plot(history.history['sparse_categorical_accuracy'])
plt.title('training model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training with SCL-RandBrightness.','training with SCL-RandContrast','training with SCL-RandSharpness','training with SCL','training without SCL'], loc='lower right')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
